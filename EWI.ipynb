# %%
pip install nasdaq-data-link
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nasdaqdatalink

# %%
# !pip install yfinance
# !pip install yahoofinancials

# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
import numpy as np

# %%
def ewi(x):
    
    yahoo_financials = YahooFinancials(x)
    data = yahoo_financials.get_historical_price_data(start_date='2007-01-05', 
                                                  end_date='2021-11-26', 
                                                  time_interval='daily')
    df = pd.DataFrame(data[x]['prices'])
    df = df.drop('date', axis=1).set_index('formatted_date')
    return df

# %%
df_1=ewi('^VIX')
df_2=ewi('CL=F')
df_3=ewi('NQ=F')
df_4=ewi('^N100')

# %%
df_5=pd.read_csv('C:/Users/K Mohan/Downloads/TEDRATE.csv')
df_6=pd.read_csv('C:/Users/K Mohan/Downloads/CPFFM.csv')

# %%
df_stfl=pd.read_csv('C:/Users/K Mohan/Downloads/STLFSI3.csv')

# %%
df_stfl
# Out:
#            DATE  STLFSI3
# 0    2007-01-05  -0.8583
# 1    2007-01-12  -1.0435
# 2    2007-01-19  -1.1829
# 3    2007-01-26  -1.2007
# 4    2007-02-02  -1.1258
# ..          ...      ...
# 773  2021-10-29  -0.6669
# 774  2021-11-05  -0.5493
# 775  2021-11-12  -0.6681
# 776  2021-11-19  -0.7063
# 777  2021-11-26  -0.4385
#
# [778 rows x 2 columns]

# %%
df_stfl=df_stfl.set_index(pd.to_datetime(df_stfl.DATE,format='%Y-%m-%d'))
df_stfl
# Out:
#                   DATE  STLFSI3
# DATE
# 2007-01-05  2007-01-05  -0.8583
# 2007-01-12  2007-01-12  -1.0435
# 2007-01-19  2007-01-19  -1.1829
# 2007-01-26  2007-01-26  -1.2007
# 2007-02-02  2007-02-02  -1.1258
# ...                ...      ...
# 2021-10-29  2021-10-29  -0.6669
# 2021-11-05  2021-11-05  -0.5493
# 2021-11-12  2021-11-12  -0.6681
# 2021-11-19  2021-11-19  -0.7063
# 2021-11-26  2021-11-26  -0.4385
#
# [778 rows x 2 columns]

# %%
df_stfl=df_stfl.drop('DATE',axis=1)

# %%
df_stfl3=df_stfl.resample('1D').bfill().reset_index()

# %%
df_stfl3.dtypes
# Out:
# DATE       datetime64[ns]
# STLFSI3           float64
# dtype: object

# %%
df_stfl_weekdays=df_stfl3[df_stfl3.DATE.dt.weekday < 5]

# %%
df_stfl_weekdays=df_stfl_weekdays.reset_index()

# %%
df_stfl_weekdays
# Out:
#       index       DATE  STLFSI3
# 0         0 2007-01-05  -0.8583
# 1         3 2007-01-08  -1.0435
# 2         4 2007-01-09  -1.0435
# 3         5 2007-01-10  -1.0435
# 4         6 2007-01-11  -1.0435
# ...     ...        ...      ...
# 3881   5435 2021-11-22  -0.4385
# 3882   5436 2021-11-23  -0.4385
# 3883   5437 2021-11-24  -0.4385
# 3884   5438 2021-11-25  -0.4385
# 3885   5439 2021-11-26  -0.4385
#
# [3886 rows x 3 columns]

# %%
df_6=df_6.set_index(pd.to_datetime(df_6.DATE,format='%Y-%m-%d'))

# %%
df_6=df_6.drop('DATE',axis=1)
df_6_daily=df_6.resample('1D').bfill().reset_index()

# %%
df_6_daily=df_6_daily.loc[(df_6_daily.DATE>'2007-01-04')&(df_6_daily.DATE<'2021-11-27')]

# %%
df_6_daily.isna().sum()
# Out:
# DATE     0
# CPFFM    0
# dtype: int64

# %%
df_6_weekday=df_6_daily[df_6_daily.DATE.dt.weekday < 5].reset_index(drop='True')

# %%
df_6_weekday.isna().sum()
# Out:
# DATE     0
# CPFFM    0
# dtype: int64

# %%
df_volatality=df_1.reset_index(drop=False)

# %%
df_volatality=df_volatality.rename(columns={'formatted_date':'DATE'})
df_volatality
# Out:
#             DATE       high        low       open      close  volume  \
# 0     2007-01-05  12.250000  11.680000  11.840000  12.140000       0
# 1     2007-01-08  12.830000  11.780000  12.480000  12.000000       0
# 2     2007-01-09  12.470000  11.690000  11.860000  11.910000       0
# 3     2007-01-10  12.500000  11.430000  12.340000  11.470000       0
# 4     2007-01-11  11.480000  10.500000  11.420000  10.870000       0
# ...          ...        ...        ...        ...        ...     ...
# 3745  2021-11-18  18.150000  16.379999  16.809999  17.590000       0
# 3746  2021-11-19  19.010000  17.230000  17.360001  17.910000       0
# 3747  2021-11-22  19.590000  17.350000  18.200001  19.170000       0
# 3748  2021-11-23  20.910000  19.030001  20.240000  19.379999       0
# 3749  2021-11-24  20.959999  18.520000  19.170000  18.580000       0
#
#        adjclose
# 0     12.140000
# 1     12.000000
# 2     11.910000
# 3     11.470000
# 4     10.870000
# ...         ...
# ...

# %%
df_commodity=df_2.reset_index(drop=False)
df_commodity=df_commodity.rename(columns={'formatted_date':'DATE'})
df_commodity
# Out:
#             DATE       high        low       open      close    volume  \
# 0     2007-01-05  56.400002  54.900002  55.410000  56.310001  250130.0
# 1     2007-01-08  57.720001  55.099998  56.240002  56.090000  298727.0
# 2     2007-01-09  56.200001  53.880001  56.119999  55.639999  333330.0
# 3     2007-01-10  55.810001  53.439999  55.750000  54.020000  282508.0
# 4     2007-01-11  54.730000  51.799999  53.590000  51.880001  341657.0
# ...          ...        ...        ...        ...        ...       ...
# 3748  2021-11-19  79.919998  75.370003  78.760002  76.099998  623448.0
# 3749  2021-11-22  77.160004  74.760002  75.750000  76.750000  465768.0
# 3750  2021-11-23  78.860001  75.300003  76.459999  78.500000  506987.0
# 3751  2021-11-24  79.230003  77.980003  78.480003  78.389999  328848.0
# 3752  2021-11-25  78.650002  77.760002  78.339996  78.029999  328848.0
#
#        adjclose
# 0     56.310001
# 1     56.090000
# 2     55.639999
# 3     54.020000
# 4     51.880001
# ...

# %%
df_futures=df_3.reset_index(drop=False)
df_futures=df_futures.rename(columns={'formatted_date':'DATE'})
df_futures
# Out:
#             DATE      high       low      open     close    volume  adjclose
# 0     2007-01-05   1816.00   1785.75   1812.75   1797.25  353652.0   1797.25
# 1     2007-01-08   1812.25   1792.25   1798.00   1803.50  267087.0   1803.50
# 2     2007-01-09   1818.75   1792.00   1803.75   1810.50  355926.0   1810.50
# 3     2007-01-10   1835.50   1798.00   1810.75   1834.50  362452.0   1834.50
# 4     2007-01-11   1856.50   1830.25   1835.00   1849.75  400929.0   1849.75
# ...          ...       ...       ...       ...       ...       ...       ...
# 3748  2021-11-19  16628.50  16490.25  16503.25  16575.00  549031.0  16575.00
# 3749  2021-11-22  16767.50  16364.50  16600.25  16382.00  770668.0  16382.00
# 3750  2021-11-23  16418.75  16118.50  16399.00  16312.00  901449.0  16312.00
# 3751  2021-11-24  16368.50  16102.00  16300.25  16366.00  656267.0  16366.00
# 3752  2021-11-25  16436.00  16352.25  16360.00  16404.50  656267.0  16404.50
#
# [3753 rows x 7 columns]

# %%
df_equity=df_4.reset_index(drop=False)
df_equity=df_equity.rename(columns={'formatted_date':'DATE'})
df_equity
# Out:
#             DATE         high          low         open        close  \
# 0     2007-01-05   966.030029   957.669983   963.700012   957.669983
# 1     2007-01-08   963.739990   957.219971   961.299988   958.690002
# 2     2007-01-09   966.849976   962.070007   963.609985   962.500000
# 3     2007-01-10   960.750000   954.010010   958.989990   957.919983
# 4     2007-01-11   973.969971   960.409973   961.739990   973.969971
# ...          ...          ...          ...          ...          ...
# 3804  2021-11-19  1387.400024  1367.349976  1385.130005  1372.650024
# 3805  2021-11-22  1378.400024  1367.640015  1376.170044  1367.739990
# 3806  2021-11-23  1364.900024  1345.849976  1356.079956  1351.770020
# 3807  2021-11-24  1359.709961  1340.869995  1354.660034  1353.390015
# 3808  2021-11-25  1362.800049  1356.619995  1359.719971  1362.229980
#
#            volume     adjclose
# 0     278706500.0   957.669983
# 1     265474600.0   958.690002
# 2     334526600.0   962.500000
# ...

# %%
df_ted=df_5.reset_index(drop=True)
df_ted=df_ted.rename(columns={'formatted_date':'DATE'})
df_ted.loc[df_ted['TEDRATE']=='.','TEDRATE']=np.nan
df_ted['TEDRATE']=df_ted['TEDRATE'].fillna(method='ffill')

# %%
df_ted['TEDRATE']=df_ted['TEDRATE'].astype(float)

# %%
df_ted['DATE']=pd.to_datetime(df_ted['DATE'])

# %%
df_cpffm=df_6_weekday.reset_index()
df_cpffm.loc[df_cpffm['CPFFM']=='.','CPFFM']=np.nan
df_cpffm['CPFFM']=df_cpffm['CPFFM'].fillna(method='ffill')

# %%
df_cpffm['CPFFM']=df_cpffm['CPFFM'].astype(float)

# %%
df_volatality
# Out:
#             DATE       high        low       open      close  volume  \
# 0     2007-01-05  12.250000  11.680000  11.840000  12.140000       0
# 1     2007-01-08  12.830000  11.780000  12.480000  12.000000       0
# 2     2007-01-09  12.470000  11.690000  11.860000  11.910000       0
# 3     2007-01-10  12.500000  11.430000  12.340000  11.470000       0
# 4     2007-01-11  11.480000  10.500000  11.420000  10.870000       0
# ...          ...        ...        ...        ...        ...     ...
# 3745  2021-11-18  18.150000  16.379999  16.809999  17.590000       0
# 3746  2021-11-19  19.010000  17.230000  17.360001  17.910000       0
# 3747  2021-11-22  19.590000  17.350000  18.200001  19.170000       0
# 3748  2021-11-23  20.910000  19.030001  20.240000  19.379999       0
# 3749  2021-11-24  20.959999  18.520000  19.170000  18.580000       0
#
#        adjclose
# 0     12.140000
# 1     12.000000
# 2     11.910000
# 3     11.470000
# 4     10.870000
# ...         ...
# ...

# %%
for col in df_volatality.columns:
    df_volatality[col+'_lag1']=df_volatality[col].shift(1)

# %%
for col in df_commodity.columns:
    df_commodity[col+'_lag1']=df_commodity[col].shift(1)

# %%
for col in df_futures.columns:
    df_futures[col+'_lag1']=df_futures[col].shift(1)

# %%
for col in df_equity.columns:
    df_equity[col+'_lag1']=df_equity[col].shift(1)

# %%
df_ted['TEDRATE_lag1']=df_ted['TEDRATE'].shift(1)

# %%
l1=['high', 'low', 'open', 'close', 'volume', 'adjclose']
for col in l1:
    df_volatality['log_return_'+col]=np.log(df_volatality[col]/df_volatality[col+'_lag1'])
    df_volatality['7-day_std_'+col] = df_volatality[col].rolling(7).std()
df_volatality['high_low']= (df_volatality['high']-df_volatality['low'])/df_volatality['low']

# %%
df_volatality_transformed = df_volatality[['DATE','log_return_high', '7-day_std_high',
       'log_return_low', '7-day_std_low', 'log_return_open', '7-day_std_open',
       'log_return_close', '7-day_std_close', 'log_return_volume',
       '7-day_std_volume', 'log_return_adjclose', '7-day_std_adjclose',
       'high_low']]

# %%
l1=['high', 'low', 'open', 'close', 'volume', 'adjclose']
for col in l1:
    df_commodity['log_return_'+col]=np.log(df_commodity[col]/df_commodity[col+'_lag1'])
    df_commodity['7-day_std_'+col] = df_commodity[col].rolling(7).std()
df_commodity['high_low']= (df_commodity['high']-df_commodity['low'])/df_commodity['low']
# Out:
# C:\Users\K Mohan\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\K Mohan\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\K Mohan\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\K Mohan\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_commodity_transformed=df_commodity[['DATE','log_return_high', '7-day_std_high',
       'log_return_low', '7-day_std_low', 'log_return_open', '7-day_std_open',
       'log_return_close', '7-day_std_close', 'log_return_close',
       '7-day_std_volume', 'log_return_adjclose', '7-day_std_adjclose',
       'high_low']]

# %%
l1=['high', 'low', 'open', 'close', 'volume', 'adjclose']
for col in l1:
    df_futures['log_return_'+col]=np.log(df_futures[col]/df_futures[col+'_lag1'])
    
df_futures['high_low']= (df_futures['high']-df_futures['low'])/df_futures['low']
# Out:
# C:\Users\K Mohan\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_futures_transformed=df_futures[['DATE','log_return_high','log_return_low','log_return_open','log_return_close','log_return_close','log_return_adjclose','high_low']]

# %%
df_futures_transformed
# Out:
#             DATE  log_return_high  log_return_low  log_return_open  \
# 0     2007-01-05              NaN             NaN              NaN
# 1     2007-01-08        -0.002067        0.003633        -0.008170
# 2     2007-01-09         0.003580       -0.000139         0.003193
# 3     2007-01-10         0.009167        0.003343         0.003873
# 4     2007-01-11         0.011376        0.017778         0.013303
# ...          ...              ...             ...              ...
# 3748  2021-11-19         0.007273        0.011389         0.011013
# 3749  2021-11-22         0.008324       -0.007655         0.005860
# 3750  2021-11-23        -0.021019       -0.015147        -0.012197
# 3751  2021-11-24        -0.003065       -0.001024        -0.006040
# 3752  2021-11-25         0.004115        0.015422         0.003659
#
#       log_return_close  log_return_close  log_return_adjclose  high_low
# 0                  NaN               NaN                  NaN  0.016940
# ...

# %%
l1=['high', 'low', 'open', 'close', 'volume', 'adjclose']
for col in l1:
    df_equity['log_return_'+col]=np.log(df_equity[col]/df_equity[col+'_lag1'])
    df_equity['7-day_std_'+col] = df_equity[col].rolling(7).std()
df_equity['high_low']= (df_equity['high']-df_equity['low'])/df_equity['low']
# Out:
# C:\Users\K Mohan\anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_equity_transformed=df_equity[['DATE','log_return_high', '7-day_std_high',
       'log_return_low', '7-day_std_low', 'log_return_open', '7-day_std_open',
       'log_return_close', '7-day_std_close', 'log_return_close',
       '7-day_std_volume', 'log_return_adjclose', '7-day_std_adjclose',
       'high_low']]

# %%
df_ted['spread']=df_ted['TEDRATE']-df_ted['TEDRATE_lag1']

# %%
df_ted_transformed=df_ted[['DATE','spread']]

# %%
 df_cpffm['7-day_std_'+'CPFFM'] = df_cpffm['CPFFM'].rolling(7).std()

# %%
 df_cpffm_transformed= df_cpffm[['DATE','7-day_std_CPFFM']]

# %%
df_volatality_transformed.columns=['DATE','log_return_high_vol', '7-day_std_high_vol',
       'log_return_low_vol', '7-day_std_low_vol', 'log_return_open_vol', '7-day_std_open_vol',
       'log_return_close_vol', '7-day_std_close_vol', 'log_return_volume_vol',
       '7-day_std_volume_vol', 'log_return_adjclose_vol', '7-day_std_adjclose_vol',
       'high_low_vol']

# %%
df_volatality
# Out:
#             DATE       high        low       open      close  volume  \
# 0     2007-01-05  12.250000  11.680000  11.840000  12.140000       0
# 1     2007-01-08  12.830000  11.780000  12.480000  12.000000       0
# 2     2007-01-09  12.470000  11.690000  11.860000  11.910000       0
# 3     2007-01-10  12.500000  11.430000  12.340000  11.470000       0
# 4     2007-01-11  11.480000  10.500000  11.420000  10.870000       0
# ...          ...        ...        ...        ...        ...     ...
# 3745  2021-11-18  18.150000  16.379999  16.809999  17.590000       0
# 3746  2021-11-19  19.010000  17.230000  17.360001  17.910000       0
# 3747  2021-11-22  19.590000  17.350000  18.200001  19.170000       0
# 3748  2021-11-23  20.910000  19.030001  20.240000  19.379999       0
# 3749  2021-11-24  20.959999  18.520000  19.170000  18.580000       0
#
#        adjclose   DATE_lag1  high_lag1   low_lag1  ...  7-day_std_low  \
# ...

# %%
df_commodity_transformed.columns=['DATE','log_return_high_com', '7-day_std_high_com',
       'log_return_low_com', '7-day_std_low_com', 'log_return_open_com', '7-day_std_open_com',
       'log_return_close_com', '7-day_std_close_com', 'log_return_close_com',
       '7-day_std_volume_com', 'log_return_adjclose_com', '7-day_std_adjclose_com',
       'high_low_com']

# %%
df_futures_transformed.columns=['DATE','log_return_high_fut','log_return_low_fut','log_return_open_fut','log_return_close_fut','log_return_close_fut','log_return_adjclose_fut','high_low_fut']

# %%
df_equity_transformed.columns=['DATE','log_return_high_equ', '7-day_std_high_equ',
       'log_return_low_equ', '7-day_std_low_equ', 'log_return_open_equ', '7-day_std_open_equ',
       'log_return_close_equ', '7-day_std_close_equ', 'log_return_close_equ',
       '7-day_std_volume_equ', 'log_return_adjclose_equ', '7-day_std_adjclose_equ',
       'high_low_equ']

# %%
data_frames = [df_volatality_transformed,df_commodity_transformed ,df_futures_transformed,df_equity_transformed,df_ted_transformed,
              df_cpffm_transformed]

# %%
df_volatality_transformed['DATE']=pd.to_datetime(df_volatality_transformed['DATE'])
df_commodity_transformed['DATE']=pd.to_datetime(df_commodity_transformed['DATE'])
df_futures_transformed['DATE']=pd.to_datetime(df_futures_transformed['DATE'])
df_equity_transformed['DATE']=pd.to_datetime(df_equity_transformed['DATE'])
# Out:
# C:\Temp\ipykernel_1860\2282184674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_volatality_transformed['DATE']=pd.to_datetime(df_volatality_transformed['DATE'])
# C:\Temp\ipykernel_1860\2282184674.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_commodity_transformed['DATE']=pd.to_datetime(df_commodity_transformed['DATE'])
# C:\Temp\ipykernel_1860\2282184674.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from functools import reduce
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['DATE'],
                                            how='outer'), data_frames)

# %%
df_merged
# Out:
#            DATE  log_return_high_vol  7-day_std_high_vol  log_return_low_vol  \
# 0    2007-01-05                  NaN                 NaN                 NaN
# 1    2007-01-08             0.046260                 NaN            0.008525
# 2    2007-01-09            -0.028460                 NaN           -0.007669
# 3    2007-01-10             0.002403                 NaN           -0.022492
# 4    2007-01-11            -0.085122                 NaN           -0.084866
# ...         ...                  ...                 ...                 ...
# 3934 2020-08-01                  NaN                 NaN                 NaN
# 3935 2020-11-01                  NaN                 NaN                 NaN
# 3936 2021-05-01                  NaN                 NaN                 NaN
# 3937 2021-08-01                  NaN                 NaN                 NaN
# 3938 2021-12-01                  NaN                 NaN                 NaN
#
# ...

# %%
df_merged=df_merged.dropna(axis=1, how='all')  #dropping column which has all null values

# %%
df_merged.isna().sum()
# Out:
# DATE                         0
# log_return_high_vol        137
# 7-day_std_high_vol         142
# log_return_low_vol         137
# 7-day_std_low_vol          142
# log_return_open_vol        137
# 7-day_std_open_vol         142
# log_return_close_vol       137
# 7-day_std_close_vol        142
# 7-day_std_volume_vol       142
# log_return_adjclose_vol    137
# 7-day_std_adjclose_vol     142
# high_low_vol               136
# log_return_high_com        142
# 7-day_std_high_com         167
# log_return_low_com         144
# 7-day_std_low_com          167
# log_return_open_com        144
# 7-day_std_open_com         167
# log_return_close_com       144
# 7-day_std_close_com        167
# log_return_close_com       144
# 7-day_std_volume_com       167
# log_return_adjclose_com    144
# 7-day_std_adjclose_com     167
# high_low_com               137
# log_return_high_fut        142
# log_return_low_fut         142
# log_return_open_fut        142
# log_return_close_fut       142
# ...

# %%
df_merged1=df_merged.dropna()
df_merged1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3660 entries, 12 to 3749
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   DATE                     3660 non-null   datetime64[ns]
#  1   log_return_high_vol      3660 non-null   float64
#  2   7-day_std_high_vol       3660 non-null   float64
#  3   log_return_low_vol       3660 non-null   float64
#  4   7-day_std_low_vol        3660 non-null   float64
#  5   log_return_open_vol      3660 non-null   float64
#  6   7-day_std_open_vol       3660 non-null   float64
#  7   log_return_close_vol     3660 non-null   float64
#  8   7-day_std_close_vol      3660 non-null   float64
#  9   7-day_std_volume_vol     3660 non-null   float64
#  10  log_return_adjclose_vol  3660 non-null   float64
#  11  7-day_std_adjclose_vol   3660 non-null   float64
#  12  high_low_vol             3660 non-null   float64
# ...

# %%
data=df_merged1.merge(df_stfl_weekdays,on='DATE',how='left')

# %%
data=data.drop('index',axis=1)

# %%
data.loc[data['STLFSI3']>1.5,'label']='red'
data.loc[data['STLFSI3']<-0.6,'label']='amber'
data.loc[data['label'].isna(),'label']='green'

# %%
data.label.value_counts()
# Out:
# green    2617
# amber     749
# red       294
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X=data.drop('label',axis=1)
y=data['label']

# %%
X_train, X_test,y_train, y_test = train_test_split(X,y ,random_state=104, test_size=0.25, shuffle=False)

# %%
# !pip install imblearn

# %%
import imblearn
from imblearn.ensemble import RUSBoostClassifier
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [142], in <cell line: 1>()
# ----> 1 import imblearn
#       2 from imblearn.ensemble import RUSBoostClassifier
#
# File ~\anaconda3\lib\site-packages\imblearn\__init__.py:52, in <module>
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import combine
#      53     from . import ensemble
#      54     from . import exceptions
#
# File ~\anaconda3\lib\site-packages\imblearn\combine\__init__.py:5, in <module>
#       1 """The :mod:`imblearn.combine` provides methods which combine
#       2 over-sampling and under-sampling.
#       3 """
# ----> 5 from ._smote_enn import SMOTEENN
# ...

# %%
# !pip uninstall sklearn --user
# Out:
# Usage:
#   pip uninstall [options] <package> ...
#   pip uninstall [options] -r <requirements file> ...
#
# no such option: --user

# %%
# !pip install sklearn
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=d8e5abe76474200c1212c7771d5bb00b5172ad155866bcc8cc05e7179f5c846a
#   Stored in directory: c:\users\k mohan\appdata\local\pip\cache\wheels\e4\7b\98\b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# ...

# %%
# !pip install --upgrade pip
# Out:
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Temp\\pip-uninstall-qmbbdhs4\\pip.exe'
# Consider using the `--user` option or check the permissions.

# %%
# !pip install --upgrade scikit-learn

# %%
from sklearn.ensemble import RandomForestClassifier
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [147], in <cell line: 1>()
# ----> 1 from sklearn.ensemble import RandomForestClassifier
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\__init__.py:5, in <module>
#       1 """
#       2 The :mod:`sklearn.ensemble` module includes ensemble-based methods for
#       3 classification, regression and anomaly detection.
#       4 """
# ----> 5 from ._base import BaseEnsemble
#       6 from ._forest import RandomForestClassifier
#       7 from ._forest import RandomForestRegressor
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:18, in <module>
#      16 from ..base import BaseEstimator
#      17 from ..base import MetaEstimatorMixin
# ---> 18 from ..tree import (
#      19     DecisionTreeRegressor,
#      20     ExtraTreeRegressor,
#      21     BaseDecisionTree,
# ...
